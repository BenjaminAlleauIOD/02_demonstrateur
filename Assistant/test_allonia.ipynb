# %%
import requests
import json
#e97dc555c65d856d
#d1bf5fdeb83f352c59db40b5cce36d84
# URL de l'API
url = "https://api.k.prod.infra.aleia.com/model-services/invoke/5de875cd-7473-47a6-a9b0-d91feb4f05f8/avis_class_new3/1ccf6d4e-7572-464d-be3a-a0a3e78c71f1"

# Exemple de données à envoyer pour la prédiction
data = {
    "text": "J'adore les produits Fleury Michon, ils sont toujours de très bonne qualité."
}

# En-têtes de la requête (si nécessaire)
headers = {
    "Content-Type": "application/json",
    "Authorization": "d1bf5fdeb83f352c59db40b5cce36d84"  # Remplacez YOUR_ACCESS_TOKEN par le token d'accès si nécessaire
}

# Envoyer la requête POST
response = requests.post(url, headers=headers, data=json.dumps(data))

# Vérifier la réponse de l'API
if response.status_code == 200:
    prediction = response.json()
    print("Prédiction:", prediction)
else:
    print("Erreur:", response.status_code, response.text)
# Out:
# Erreur: 401 {"status":401,"error":"No authorization found in request"}

# %%
import requests

endpoint="https://api.k.prod.infra.aleia.com/model-services/invoke/5de875cd-7473-47a6-a9b0-d91feb4f05f8/avis_class_new3/1ccf6d4e-7572-464d-be3a-a0a3e78c71f1"
response = requests.post(endpoint, json={"meta": {"d1bf5fdeb83f352c59db40b5cce36d84"}, "data": {"names": ["d1bf5fdeb83f352c59db40b5cce36d84"], "ndarray": ["d1bf5fdeb83f352c59db40b5cce36d84"]}})
print(response.json())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 import requests
#       3 endpoint="https://api.k.prod.infra.aleia.com/model-services/invoke/5de875cd-7473-47a6-a9b0-d91feb4f05f8/avis_class_new3/1ccf6d4e-7572-464d-be3a-a0a3e78c71f1"
# ----> 4 response = requests.post(endpoint, json={"meta": {"d1bf5fdeb83f352c59db40b5cce36d84"}, "data": {"names": ["d1bf5fdeb83f352c59db40b5cce36d84"], "ndarray": ["d1bf5fdeb83f352c59db40b5cce36d84"]}})
#       5 print(response.json())
#
# File c:\Users\benja\Documents\projets\02_demonstrateur\.venv\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# ...
